# %% [markdown]
# # plotting iSNVs across the tranamission event and highlight interesting iSNVs

# %%
import pandas as pd
import numpy as np
# from sklearn.decomposition import PCA
# from sklearn import preprocessing
import matplotlib.pyplot as plt
import glob
import os
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pathlib import Path
from os.path import splitext
from functools import reduce
from pandas.api.types import is_numeric_dtype
import warnings
from pandas.core.common import SettingWithCopyWarning
from matplotlib.font_manager import FontProperties 
from matplotlib import cm
import itertools
from matplotlib import container
from matplotlib import gridspec
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.lines as mlines
import matplotlib as mpl
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## transmission events
#
# 1. HPAI DPI 3 --> DPI 5
# 2. LPAI DPI 1 --> DPI 3
# 3. CA04 1: DPI 1 --> DPI 3
# 4. CA04 2: DPI 1 --> DPI 3
# 5. CA04 3: DPI 1 --> DPI 3
# 6. CA04 4: DPI 1 --> DPI 3
# 7. rGD3wt 1: DPI 1 --> DPI 3
# 8. rGD3 wt 2: DPI 1 --> DPI 3
# 9. rGD3 wt 3: DPI 1 --> DPI 3
# 10. rGD3 escape 1: DPI 7 --> DPI 11
# 11. rGD3 escape 2: DPI 1 --> DPI 3

# %%
HPAI_1 = pd.read_csv('../data_derived/iSNVs-over-time/pair_1_GD3.csv', sep='\t')
HPAI_1 = HPAI_1[['SNP', 'day3_index', 'day5_contact']]

HPAI_1 = HPAI_1.set_index('SNP')
HPAI_1 = HPAI_1.T

fig = plt.figure(figsize=(6,6), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1,6)
ax1 = fig.add_subplot(gs[0,0:6]) #PB2

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.ylim([-0.05, 1.05])

HPAI_1.plot(kind='line', ax=ax1, linewidth=3, alpha=0.6, legend=False)

#label axes and add title 
plt.title('Anhui/1, pair1, DPI 3 --> DPI 5', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection/inoculation', fontsize=12)

plt.savefig('../figures/iSNVs_across_transmission/Anhui_pair1.pdf', dpi=300)


#

# %%
LPAI_1 = pd.read_csv('../data_derived/iSNVs-over-time/pair_1_Anhui.csv', sep='\t')
LPAI_1 = LPAI_1[['SNP', 'day1_index', 'day3_contact']]

LPAI_1 = LPAI_1.set_index('SNP')
LPAI_1 = LPAI_1.T

fig = plt.figure(figsize=(6,6), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1,6)
ax1 = fig.add_subplot(gs[0,0:6]) #PB2

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.ylim([-0.05, 1.05])

LPAI_1.plot(kind='line', ax=ax1, linewidth=3, alpha=0.6, legend=False)

#label axes and add title 
plt.title('GD/3, pair1, DPI 1 --> DPI 3', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection/inoculation', fontsize=12)

plt.savefig('../figures/iSNVs_across_transmission/GD3_pair1.pdf', dpi=300)

#

# %%
CA04_1 = pd.read_csv('../data_derived/iSNVs-over-time/pair_1_CA04.csv', sep='\t')
CA04_1 = CA04_1[['SNP', 'day1_index', 'day3_contact']]

CA04_1 = CA04_1.set_index('SNP')
CA04_1 = CA04_1.T

fig = plt.figure(figsize=(6,6), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1,6)
ax1 = fig.add_subplot(gs[0,0:6]) #PB2

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.ylim([-0.05, 1.05])

CA04_1.plot(kind='line', ax=ax1, linewidth=3, alpha=0.6, legend=False)

#label axes and add title 
plt.title('CA04, pair1, DPI 1 --> DPI 3', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection/inoculation', fontsize=12)

plt.savefig('../figures/iSNVs_across_transmission/CA04_pair1.pdf', dpi=300)

#

# %%
CA04_2 = pd.read_csv('../data_derived/iSNVs-over-time/pair_2_CA04.csv', sep='\t')
CA04_2 = CA04_2[['SNP', 'day1_index', 'day3_contact']]

CA04_2 = CA04_2.set_index('SNP')
CA04_2 = CA04_2.T

fig = plt.figure(figsize=(6,6), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1,6)
ax1 = fig.add_subplot(gs[0,0:6]) #PB2

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.ylim([-0.05, 1.05])

CA04_2.plot(kind='line', ax=ax1, linewidth=3, alpha=0.6, legend=False)

#label axes and add title 
plt.title('CA04, pair2, DPI 1 --> DPI 3', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection/inoculation', fontsize=12)

plt.savefig('../figures/iSNVs_across_transmission/CA04_pair2.pdf', dpi=300)


#

# %%
CA04_3 = pd.read_csv('../data_derived/iSNVs-over-time/pair_3_CA04.csv', sep='\t')
CA04_3 = CA04_3[['SNP', 'day1_index', 'day3_contact']]

CA04_3 = CA04_3.set_index('SNP')
CA04_3 = CA04_3.T

fig = plt.figure(figsize=(6,6), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1,6)
ax1 = fig.add_subplot(gs[0,0:6]) #PB2

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.ylim([-0.05, 1.05])

CA04_3.plot(kind='line', ax=ax1, linewidth=3, alpha=0.6, legend=False)

#label axes and add title 
plt.title('CA04, pair3, DPI 1 --> DPI 3', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection/inoculation', fontsize=12)

plt.savefig('../figures/iSNVs_across_transmission/CA04_pair3.pdf', dpi=300)


#

# %%
CA04_4 = pd.read_csv('../data_derived/iSNVs-over-time/pair_4_CA04.csv', sep='\t')
CA04_4 = CA04_4[['SNP', 'day1_index', 'day3_contact']]

CA04_4 = CA04_4.set_index('SNP')
CA04_4 = CA04_4.T

fig = plt.figure(figsize=(6,6), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1,6)
ax1 = fig.add_subplot(gs[0,0:6]) #PB2

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.ylim([-0.05, 1.05])

CA04_4.plot(kind='line', ax=ax1, linewidth=3, alpha=0.6, legend=False)

#label axes and add title 
plt.title('CA04, pair4, DPI 1 --> DPI 3', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection/inoculation', fontsize=12)

plt.savefig('../figures/iSNVs_across_transmission/CA04_pair4.pdf', dpi=300)


#

# %%
rGD3wt_1 = pd.read_csv('../data_derived/iSNVs-over-time/pair_1_rGD3.csv', sep='\t')
rGD3wt_1 = rGD3wt_1[['SNP', 'day1_index', 'day3_contact']]

rGD3wt_1 = rGD3wt_1.set_index('SNP')
rGD3wt_1 = rGD3wt_1.T

fig = plt.figure(figsize=(6,6), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1,6)
ax1 = fig.add_subplot(gs[0,0:6]) #PB2

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.ylim([-0.05, 1.05])

rGD3wt_1.plot(kind='line', ax=ax1, linewidth=3, alpha=0.6, legend=False)

#label axes and add title 
plt.title('rGD3 wt, pair1, DPI 1 --> DPI 3', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection/inoculation', fontsize=12)

plt.savefig('../figures/iSNVs_across_transmission/rGD3wt_pair1.pdf', dpi=300)


#

# %%
rGD3wt_2 = pd.read_csv('../data_derived/iSNVs-over-time/pair_2_rGD3.csv', sep='\t')
rGD3wt_2 = rGD3wt_2[['SNP', 'day1_index', 'day3_contact']]

rGD3wt_2 = rGD3wt_2.set_index('SNP')
rGD3wt_2 = rGD3wt_2.T

fig = plt.figure(figsize=(6,6), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1,6)
ax1 = fig.add_subplot(gs[0,0:6]) #PB2

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.ylim([-0.05, 1.05])

rGD3wt_2.plot(kind='line', ax=ax1, linewidth=3, alpha=0.6, legend=False)

#label axes and add title 
plt.title('rGD3 wt, pair2, DPI 1 --> DPI 3', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection/inoculation', fontsize=12)

plt.savefig('../figures/iSNVs_across_transmission/rGD3wt_pair2.pdf', dpi=300)


#

# %%
rGD3wt_3 = pd.read_csv('../data_derived/iSNVs-over-time/pair_3_rGD3.csv', sep='\t')
rGD3wt_3 = rGD3wt_3[['SNP', 'day1_index', 'day3_contact']]

rGD3wt_3 = rGD3wt_3.set_index('SNP')
rGD3wt_3 = rGD3wt_3.T

fig = plt.figure(figsize=(6,6), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1,6)
ax1 = fig.add_subplot(gs[0,0:6]) #PB2

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.ylim([-0.05, 1.05])

rGD3wt_3.plot(kind='line', ax=ax1, linewidth=3, alpha=0.6, legend=False)

#label axes and add title 
plt.title('rGD3 wt, pair3, DPI 1 --> DPI 3', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection/inoculation', fontsize=12)

plt.savefig('../figures/iSNVs_across_transmission/rGD3wt_pair3.pdf', dpi=300)


#

# %%
rGD3escape_1 = pd.read_csv('../data_derived/iSNVs-over-time/pair_4_rGD3.csv', sep='\t')
rGD3escape_1 = rGD3escape_1[['SNP', 'day7_index', 'day11_contact']]

rGD3escape_1 = rGD3escape_1.set_index('SNP')
rGD3escape_1 = rGD3escape_1.T

fig = plt.figure(figsize=(6,6), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1,6)
ax1 = fig.add_subplot(gs[0,0:6]) #PB2

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.ylim([-0.05, 1.05])

rGD3escape_1.plot(kind='line', ax=ax1, linewidth=3, alpha=0.6, legend=False)

#label axes and add title 
plt.title('rGD3 escape, pair1, DPI 7 --> DPI 11', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection/inoculation', fontsize=12)

plt.savefig('../figures/iSNVs_across_transmission/rGD3escape_pair1.pdf', dpi=300)


#

# %%
rGD3escape_2 = pd.read_csv('../data_derived/iSNVs-over-time/pair_5_rGD3.csv', sep='\t')
rGD3escape_2 = rGD3escape_2[['SNP', 'day1_index', 'day3_contact']]

rGD3escape_2 = rGD3escape_2.set_index('SNP')
rGD3escape_2 = rGD3escape_2.T

fig = plt.figure(figsize=(6,6), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1,6)
ax1 = fig.add_subplot(gs[0,0:6]) #PB2

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.ylim([-0.05, 1.05])

rGD3escape_2.plot(kind='line', ax=ax1, linewidth=3, alpha=0.6, legend=False)

#label axes and add title 
plt.title('rGD3 escape, pair2, DPI 1 --> DPI 3', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection/inoculation', fontsize=12)

plt.savefig('../figures/iSNVs_across_transmission/rGD3escape_pair2.pdf', dpi=300)



#

# %%
## pull out representative iSNVs across transmission events

# %%
anhui_1 = pd.read_csv('../data_derived/iSNVs-over-time/pair_1_Anhui.csv', sep='\t')
# anhui_1 = anhui_1[['SNP', 'day1_index', 'day3_contact']]

anhui_s = anhui_1[anhui_1['SNP'].str.contains('HA_A499G_N167D')]
anhui_t = anhui_1[anhui_1['SNP'].str.contains('HA_A421G_N141D')]
anhui_u = anhui_1[anhui_1['SNP'].str.contains('NA_C29T_T10I')]
anhui_v = anhui_1[anhui_1['SNP'].str.contains('NEP_A698G_I76V')]
anhui_x = anhui_1[anhui_1['SNP'].str.contains('PB2_C990T_syn')]
anhui_y = anhui_1[anhui_1['SNP'].str.contains('NP_G1117A_A373T')]

anhui = pd.concat([anhui_s, anhui_t, anhui_u, anhui_v, anhui_x, anhui_y], axis=0)

anhui = anhui.set_index('SNP')
# anhui = anhui.T

# %%
anhui_i = anhui[['day1_index', 'day3_index', 'day5_index', 'day7_index']]
anhui_i[['','']] = pd.DataFrame([[np.nan,np.nan]], index=anhui_i.index)
anhui_i = anhui_i[['','day1_index', 'day3_index', 'day5_index', 'day7_index','']]
# anhui_i = anhui_i.replace(0, np.nan)

anhui_c = anhui[['day3_contact', 'day5_contact']]
anhui_c[['day7_contact', 'day9_contact','','']] = pd.DataFrame([[ np.nan, np.nan, np.nan, np.nan]], index=anhui_c.index)
anhui_c = anhui_c[['','day3_contact','day5_contact','day7_contact', 'day9_contact','']]
# anhui_c = anhui_c.replace(0, np.nan)

anhui_i_N167D = anhui_i.iloc[0]
anhui_i_N141D = anhui_i.iloc[1]
anhui_i_T10I = anhui_i.iloc[2]
anhui_i_I76V = anhui_i.iloc[3]
anhui_i_PB2syn = anhui_i.iloc[4]
anhui_i_A373T = anhui_i.iloc[5]

anhui_c_N167D = anhui_c.iloc[0]
anhui_c_N141D = anhui_c.iloc[1]
anhui_c_T10I = anhui_c.iloc[2]
anhui_c_I76V = anhui_c.iloc[3]
anhui_c_PB2syn = anhui_c.iloc[4]
anhui_c_A373T = anhui_c.iloc[5]

anhui_i_N167D = anhui_i_N167D.T
anhui_i_N141D = anhui_i_N141D.T
anhui_i_T10I = anhui_i_T10I.T
anhui_i_I76V = anhui_i_I76V.T
anhui_i_PB2syn = anhui_i_PB2syn.T
anhui_i_A373T = anhui_i_A373T.T

anhui_c_N167D = anhui_c_N167D.T
anhui_c_N141D = anhui_c_N141D.T
anhui_c_T10I = anhui_c_T10I.T
anhui_c_I76V = anhui_c_I76V.T
anhui_c_PB2syn = anhui_c_PB2syn.T
anhui_c_A373T = anhui_c_A373T.T

#

# %%
# plot the index iSNVs for Anhui

fig = plt.figure(figsize=(16,10), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(3,14)
ax1 = fig.add_subplot(gs[0,1:8]) #index

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
plt.ylim([-0.05, 1.05])

anhui_i_N141D.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='s', markersize=7, color='#3C7067', clip_on=False)
anhui_i_N167D.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='o', markersize=7, color='#3C7067', clip_on=False)
anhui_i_T10I.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='*', markersize=10, color='#3C7067', clip_on=False)
anhui_i_I76V.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='^', markersize=8, color='#3C7067', clip_on=False)
anhui_i_PB2syn.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='d', markersize=8, color='#3C7067', clip_on=False)
anhui_i_A373T.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='P', markersize=8, color='#3C7067', clip_on=False)

#label axes and add title 
plt.title('', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection', fontsize=12)

x = np.arange(1,5,1)
x_ticks_labels = ['day 1', 'day 3', 'day 5', 'day 7']

ax1.set_xticks(x)
ax1.set_xticklabels(x_ticks_labels, rotation='horizontal', fontsize=12)

ax1.legend(bbox_to_anchor=[1.3,1], frameon=False, fontsize=10, ncol=1)

plt.savefig('../figures/iSNVs_across_transmission/interesting_iSNVs_Anhui_index.pdf', dpi=300)

# %%
# plot the contact iSNVs for Anhui

fig = plt.figure(figsize=(16,10), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(3,14)
ax1 = fig.add_subplot(gs[0,1:8]) #index

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
plt.ylim([-0.05, 1.05])

anhui_c_N141D.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='s', markersize=7, color='#3C7067', clip_on=False)
anhui_c_N167D.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='o', markersize=7, color='#3C7067', clip_on=False)
anhui_c_T10I.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='*', markersize=10, color='#3C7067', clip_on=False)
anhui_c_I76V.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='^', markersize=8, color='#3C7067', clip_on=False)
anhui_c_PB2syn.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='d', markersize=8, color='#3C7067', clip_on=False)
anhui_c_A373T.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='P', markersize=8, color='#3C7067', clip_on=False)

#label axes and add title 
plt.title('', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection', fontsize=12)

x = np.arange(1,5,1)
x_ticks_labels = ['day 3', 'day 5', '', '']

ax1.set_xticks(x)
ax1.set_xticklabels(x_ticks_labels, rotation='horizontal', fontsize=12)


ax1.legend(bbox_to_anchor=[1.3,1], frameon=False, fontsize=10, ncol=1)

plt.savefig('../figures/iSNVs_across_transmission/interesting_iSNVs_Anhui_contact.pdf', dpi=300)

# %%
CA04_1 = pd.read_csv('../data_derived/iSNVs-over-time/pair_1_CA04.csv', sep='\t')

CA04_s = CA04_1[CA04_1['SNP'].str.contains('HA_C432A_D144E')]
CA04_u = CA04_1[CA04_1['SNP'].str.contains('HA_A436G_N146D')]
CA04_v = CA04_1[CA04_1['SNP'].str.contains('HA_T598C_S200P')]

CA04_2 = pd.read_csv('../data_derived/iSNVs-over-time/pair_2_CA04.csv', sep='\t')

CA04_t = CA04_2[CA04_2['SNP'].str.contains('HA_G1188A_syn')]
CA04_w = CA04_2[CA04_2['SNP'].str.contains('NP_G568A_A190T')]

CA04 = pd.concat([CA04_s, CA04_u, CA04_t, CA04_v, CA04_w], axis=0)

CA04 = CA04.set_index('SNP')
# CA04 = CA04.T

# %%
CA04_i = CA04[['day1_index', 'day3_index', 'day5_index']]
CA04_i[['','day7_index','']] = pd.DataFrame([[ np.nan, np.nan, np.nan]], index=CA04_i.index)
CA04_i = CA04_i[['','day1_index', 'day3_index', 'day5_index', 'day7_index','']]
# CA04_i = CA04_i.replace(0, np.nan)

CA04_c = CA04[['day3_contact', 'day5_contact']]
CA04_c[['','','day7_contact', 'day9_contact']] = pd.DataFrame([[np.nan, np.nan,np.nan, np.nan]], index=CA04_c.index)
CA04_c = CA04_c[['','day3_contact','day5_contact', 'day7_contact', 'day9_contact','']]
# CA04_c = CA04_c.replace(0, np.nan)

CA04_i_C432A = CA04_i.iloc[0]
CA04_i_A436G = CA04_i.iloc[1]
CA04_i_G1188A = CA04_i.iloc[2]
CA04_i_T598C = CA04_i.iloc[3]
CA04_i_G568A = CA04_i.iloc[4]

CA04_c_C432A = CA04_c.iloc[0]
CA04_c_A436G = CA04_c.iloc[1] 
CA04_c_G1188A = CA04_c.iloc[2]
CA04_c_T598C = CA04_c.iloc[3]
CA04_c_G568A = CA04_c.iloc[4]

CA04_i_C432A = CA04_i_C432A.T
CA04_i_T598C = CA04_i_T598C.T
CA04_i_G1188A = CA04_i_G1188A.T
CA04_i_A436G = CA04_i_A436G.T
CA04_i_G568A = CA04_i_G568A.T

CA04_c_C432A = CA04_c_C432A.T
CA04_c_T598C = CA04_c_T598C.T
CA04_c_G1188A = CA04_c_G1188A.T
CA04_c_A436G = CA04_c_A436G.T
CA04_c_G568A = CA04_c_G568A.T

#

# %%
# plot the index iSNVs for CA04

fig = plt.figure(figsize=(16,10), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(3,14)
ax1 = fig.add_subplot(gs[0,1:8]) #index

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.ylim([-0.05, 1.05])

CA04_i_C432A.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='s', markersize=7, color='#C15D1A', clip_on=False)
CA04_i_A436G.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='o', markersize=7, color='#C15D1A', clip_on=False)
CA04_i_G1188A.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='*', markersize=10, color='#C15D1A', clip_on=False)
CA04_i_T598C.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='^', markersize=8, color='#C15D1A', clip_on=False)
CA04_i_G568A.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='d', markersize=8, color='#C15D1A', clip_on=False)

#label axes and add title 
plt.title('', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection', fontsize=12)

x = np.arange(1,5,1)
x_ticks_labels = ['day 1', 'day 3', 'day 5', '']

ax1.set_xticks(x)
ax1.set_xticklabels(x_ticks_labels, rotation='horizontal', fontsize=12)

ax1.legend(bbox_to_anchor=[1.3,1], frameon=False, fontsize=10, ncol=1)

plt.savefig('../figures/iSNVs_across_transmission/interesting_iSNVs_CA04_index.pdf', dpi=300)

# %%
# plot the contact iSNVs for CA04

fig = plt.figure(figsize=(16,10), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(3,14)
ax1 = fig.add_subplot(gs[0,1:8]) #index

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.ylim([-0.05, 1.05])

CA04_c_C432A.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='s', markersize=7, color='#C15D1A', clip_on=False)
CA04_c_A436G.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='o', markersize=7, color='#C15D1A', clip_on=False)
CA04_c_G1188A.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='*', markersize=10, color='#C15D1A', clip_on=False)
CA04_c_T598C.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='^', markersize=8, color='#C15D1A', clip_on=False)
CA04_c_G568A.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='d', markersize=8, color='#C15D1A', clip_on=False)

#label axes and add title 
plt.title('', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection', fontsize=12)

x = np.arange(1,5,1)
x_ticks_labels = ['day 3', 'day 5', '', '']

ax1.set_xticks(x)
ax1.set_xticklabels(x_ticks_labels, rotation='horizontal', fontsize=12)


ax1.legend(bbox_to_anchor=[1.3,1], frameon=False, fontsize=10, ncol=1)

plt.savefig('../figures/iSNVs_across_transmission/interesting_iSNVs_CA04_contact.pdf', dpi=300)

# %%
GD3_1 = pd.read_csv('../data_derived/iSNVs-over-time/pair_1_GD3.csv', sep='\t')

GD3_s = GD3_1[GD3_1['SNP'].str.contains('HA_G410A_G137E')]
GD3_t = GD3_1[GD3_1['SNP'].str.contains('PB1_A2037G_syn')]
GD3_u = GD3_1[GD3_1['SNP'].str.contains('M1_G629A_R210K')]
GD3_v = GD3_1[GD3_1['SNP'].str.contains('M1_G655A_V219I')]
GD3_w = GD3_1[GD3_1['SNP'].str.contains('PB2_G2101A_D701N')]
GD3 = pd.concat([GD3_s, GD3_t, GD3_u, GD3_v, GD3_w], axis=0)

GD3 = GD3.set_index('SNP')
# GD3 = GD3.T

# %%
GD3_i = GD3[['day1_index', 'day3_index', 'day5_index', 'day7_index']]
GD3_i[['','']] = pd.DataFrame([[np.nan,np.nan]], index=GD3_i.index)
GD3_i = GD3_i[['','day1_index', 'day3_index', 'day5_index', 'day7_index','']]
# GD3_i = GD3_i.replace(0, np.nan)

GD3_c = GD3[['day5_contact', 'day7_contact', 'day9_contact']]
GD3_c[['','','day3_contact']] = pd.DataFrame([[np.nan,np.nan,np.nan]], index=GD3_c.index)
GD3_c = GD3_c[['','day3_contact','day5_contact', 'day7_contact', 'day9_contact','']]
# GD3_c = GD3_c.replace(0, np.nan)

GD3_i_G137E = GD3_i.iloc[0]
GD3_i_A2037G = GD3_i.iloc[1]
GD3_i_G629A = GD3_i.iloc[2]
GD3_i_G655A = GD3_i.iloc[3]
GD3_i_G2101A = GD3_i.iloc[4]

GD3_c_G137E = GD3_c.iloc[0]
GD3_c_A2037G = GD3_c.iloc[1]
GD3_c_G629A = GD3_c.iloc[2] 
GD3_c_G655A = GD3_c.iloc[3] 
GD3_c_G2101A = GD3_c.iloc[4]

GD3_i_G137E = GD3_i_G137E.T
GD3_i_A2037G = GD3_i_A2037G.T
GD3_i_G629A = GD3_i_G629A.T
GD3_i_G655A = GD3_i_G655A.T
GD3_i_G2101A = GD3_i_G2101A.T

GD3_c_G137E = GD3_c_G137E.T
GD3_c_A2037G = GD3_c_A2037G.T
GD3_c_G629A = GD3_c_G629A.T
GD3_c_G655A = GD3_c_G655A.T
GD3_c_G2101A = GD3_c_G2101A.T
#

# %%
# plot the index iSNVs for GD3

fig = plt.figure(figsize=(16,10), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(3,14)
ax1 = fig.add_subplot(gs[0,1:8]) #index

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.ylim([-0.05, 1.05])

GD3_i_A2037G.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='s', markersize=7, color='#00A1C6', clip_on=False)
GD3_i_G137E.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='o', markersize=7, color='#00A1C6', clip_on=False)
GD3_i_G629A.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='*', markersize=10, color='#00A1C6', clip_on=False)
GD3_i_G655A.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='^', markersize=8, color='#00A1C6', clip_on=False)
GD3_i_G2101A.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='d', markersize=8, color='#00A1C6', clip_on=False)

#label axes and add title 
plt.title('', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection', fontsize=12)

plt.title('', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection', fontsize=12)

x = np.arange(1,5,1)
x_ticks_labels = ['day 1', 'day 3', 'day 5', 'day 7']

ax1.set_xticks(x)
ax1.set_xticklabels(x_ticks_labels, rotation='horizontal', fontsize=12)

ax1.legend(bbox_to_anchor=[1.3,1], frameon=False, fontsize=10, ncol=1)

plt.savefig('../figures/iSNVs_across_transmission/interesting_iSNVs_GD3_index.pdf', dpi=300)

# %%
# plot the contact iSNVs for GD3

fig = plt.figure(figsize=(16,10), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(3,14)
ax1 = fig.add_subplot(gs[0,1:8]) #index

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)

# set fontsize of axes  
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.ylim([-0.05, 1.05])

GD3_c_A2037G.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='s', markersize=7, color='#00A1C6', clip_on=False)
GD3_c_G137E.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='o', markersize=7, color='#00A1C6', clip_on=False)
GD3_c_G629A.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='*', markersize=10, color='#00A1C6', clip_on=False)
GD3_c_G655A.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='^', markersize=8, color='#00A1C6', clip_on=False)
GD3_c_G2101A.plot(kind='line', ax=ax1, linestyle='dashed', linewidth=1.5, alpha=1, marker='d', markersize=8, color='#00A1C6', clip_on=False)

#label axes and add title 
plt.title('', fontsize=14)
plt.ylabel('iSNV frequency \n', fontsize=12)
plt.xlabel('\n days post infection', fontsize=12)

x = np.arange(1,5,1)
x_ticks_labels = ['day 3', 'day 5', 'day 7', 'day 9']

ax1.set_xticks(x)
ax1.set_xticklabels(x_ticks_labels, rotation='horizontal', fontsize=12)


ax1.legend(bbox_to_anchor=[1.3,1], frameon=False, fontsize=10, ncol=1)

plt.savefig('../figures/iSNVs_across_transmission/interesting_iSNVs_GD3_contact.pdf', dpi=300)
